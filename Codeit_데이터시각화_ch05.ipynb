# %%
# %matplotlib inline
import pandas as pd

# %%
df=pd.read_csv("C:/Users/gksal/Downloads/broadcast.csv",index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['KBS']+df['MBC']+df['SBS']+df['TV CHOSUN']+df['JTBC']+df['Channel A']+df['MBN']
# Out:
# 2011    88.560
# 2012    89.440
# 2013    84.451
# 2014    83.259
# 2015    82.854
# 2016    80.891
# 2017    77.626
# dtype: float64

# %%
df.sum(axis='columns')
# Out:
# 2011    88.560
# 2012    89.440
# 2013    84.451
# 2014    83.259
# 2015    82.854
# 2016    80.891
# 2017    77.626
# dtype: float64

# %%
df['Total']=df.sum(axis='columns')
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN   Total
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809  88.560
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310  89.440
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825  84.451
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572  83.259
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520  82.854
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477  80.891
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215  77.626

# %%
df.plot(y='Total')
# Out:
# <AxesSubplot:>

# %%
df['KBS']+df['MBC']+df['SBS']

df.loc[:,'KBS':'SBS'].sum(axis='columns')
df['Group1'] = df.loc[:,'KBS':'SBS'].sum(axis='columns')
df['Group2']= df.loc[:,'TV CHOSUN':'MBN'].sum(axis='columns')

# %%
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN   Total  \
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809  88.560
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310  89.440
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825  84.451
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572  83.259
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520  82.854
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477  80.891
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215  77.626
#
#       Group1  Group2
# 2011  65.498  23.062
# 2012  63.593  25.847
# 2013  58.440  26.011
# 2014  55.981  27.278
# 2015  53.449  29.405
# 2016  51.234  29.657
# 2017  48.016  29.610

# %%
df.plot(y=['Group1','Group2'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 2. 문자열 필터링

# %%
# %matplotlib inline
import pandas as pd
df = pd.read_csv("C:/Users/gksal/Downloads/albums.csv",encoding = 'latin1')

# %%
df.head(20)
# Out:
#         Year                                  Album  \
# Number
# 1       1967  Sgt. Pepper's Lonely Hearts Club Band
# 2       1966                             Pet Sounds
# 3       1966                               Revolver
# 4       1965                   Highway 61 Revisited
# 5       1965                            Rubber Soul
# 6       1971                        What's Going On
# 7       1972                      Exile on Main St.
# 8       1979                         London Calling
# 9       1966                       Blonde on Blonde
# 10      1968        The Beatles ("The White Album")
# 11      1976                       The Sun Sessions
# 12      1959                           Kind of Blue
# 13      1967          The Velvet Underground & Nico
# 14      1969                             Abbey Road
# 15      1967                    Are You Experienced
# 16      1975                    Blood on the Tracks
# 17      1991                              Nevermind
# ...

# %%
df['Genre'].unique()
# Out:
# array(['Rock', 'Rock, Pop', 'Funk / Soul', 'Rock, Blues', 'Jazz',
#        'Jazz, Rock, Blues, Folk, World, & Country', 'Funk / Soul, Pop',
#        'Blues', 'Pop', 'Rock, Folk, World, & Country',
#        'Folk, World, & Country', 'Classical, Stage & Screen', 'Reggae',
#        'Hip Hop', 'Jazz, Funk / Soul', 'Rock, Funk / Soul, Pop',
#        'Electronic, Rock',
#        'Jazz, Rock, Funk / Soul, Folk, World, & Country',
#        'Jazz, Rock, Funk / Soul, Pop, Folk, World, & Country',
#        'Funk / Soul, Stage & Screen',
#        'Electronic, Rock, Funk / Soul, Stage & Screen',
#        'Rock, Funk / Soul', 'Rock, Reggae', 'Jazz, Pop',
#        'Funk / Soul, Folk, World, & Country', 'Latin, Funk / Soul',
#        'Funk / Soul, Blues',
#        'Reggae,�Pop,�Folk, World, & Country,�Stage & Screen',
#        'Electronic,�Stage & Screen', 'Jazz, Rock, Funk / Soul, Blues',
#        'Jazz, Rock', 'Rock, Latin, Funk / Soul', 'Electronic, Rock, Pop',
# ...

# %%
df[df['Genre']=='Blues']
# Out:
#         Year                               Album           Artist  Genre  \
# Number
# 22      1990             The Complete Recordings   Robert Johnson  Blues
# 141     1965                   Live at the Regal        B.B. King  Blues
# 154     1958            Moanin' in the Moonlight     Howlin' Wolf  Blues
# 198     1967           The Best of Little Walter    Little Walter  Blues
# 238     1962                        Howlin' Wolf     Howlin' Wolf  Blues
# 282     1964                         Folk Singer     Muddy Waters  Blues
# 377     1991  The Ultimate Collection: 1948-1990  John Lee Hooker  Blues
# 499     1971            Live in Cook County Jail        B.B. King  Blues
#
#                                                  Subgenre
# Number
# 22                                            Delta Blues
# 141                                         Chicago Blues
# 154                                         Chicago Blues
# 198                                         Chicago Blues
# ...

# %%
df[df['Genre'].str.contains('Blues')]
# Out:
#         Year                                              Album  \
# Number
# 9       1966                                   Blonde on Blonde
# 15      1967                                Are You Experienced
# 19      1968                                       Astral Weeks
# 22      1990                            The Complete Recordings
# 49      1971                                   At Fillmore East
# 50      1957                              Here's Little Richard
# 55      1968                                  Electric Ladyland
# 60      1969                                 Trout Mask Replica
# 102     1966                                        Fresh Cream
# 119     1960                                           At Last!
# 125     1971                                              Pearl
# 141     1965                                  Live at the Regal
# 143     1968                                          Gris-Gris
# ...

# %%
df[df['Genre'].str.startswith('Blues')]
# Out:
#         Year                               Album           Artist  \
# Number
# 22      1990             The Complete Recordings   Robert Johnson
# 141     1965                   Live at the Regal        B.B. King
# 154     1958            Moanin' in the Moonlight     Howlin' Wolf
# 198     1967           The Best of Little Walter    Little Walter
# 238     1962                        Howlin' Wolf     Howlin' Wolf
# 278     1997    Anthology of American Folk Music          Various
# 282     1964                         Folk Singer     Muddy Waters
# 377     1991  The Ultimate Collection: 1948-1990  John Lee Hooker
# 499     1971            Live in Cook County Jail        B.B. King
#
#                                 Genre  \
# Number
# 22                              Blues
# 141                             Blues
# 154                             Blues
# 198                             Blues
# 238                             Blues
# 278     Blues, Folk, World, & Country
# ...

# %%
df['Contains Blues'] = df['Genre'].str.contains('Blues')
df
# Out:
#         Year                                  Album             Artist  \
# Number
# 1       1967  Sgt. Pepper's Lonely Hearts Club Band        The Beatles
# 2       1966                             Pet Sounds     The Beach Boys
# 3       1966                               Revolver        The Beatles
# 4       1965                   Highway 61 Revisited          Bob Dylan
# 5       1965                            Rubber Soul        The Beatles
# ...      ...                                    ...                ...
# 496     1969                             Boz Scaggs         Boz Scaggs
# 497     2001                      White Blood Cells  The White Stripes
# 498     1989                        The Stone Roses    The Stone Roses
# 499     1971               Live in Cook County Jail          B.B. King
# 500     1998                               Aquemini            OutKast
#
#             Genre                                           Subgenre  \
# Number
# ...

# %%
df['Start with Blues']=df['Genre'].str.startswith("Blues")
df['The Beatles'] = df['Artist'].str.contains('The Beatles')
df
# Out:
#         Year                                  Album             Artist  \
# Number
# 1       1967  Sgt. Pepper's Lonely Hearts Club Band        The Beatles
# 2       1966                             Pet Sounds     The Beach Boys
# 3       1966                               Revolver        The Beatles
# 4       1965                   Highway 61 Revisited          Bob Dylan
# 5       1965                            Rubber Soul        The Beatles
# ...      ...                                    ...                ...
# 496     1969                             Boz Scaggs         Boz Scaggs
# 497     2001                      White Blood Cells  The White Stripes
# 498     1989                        The Stone Roses    The Stone Roses
# 499     1971               Live in Cook County Jail          B.B. King
# 500     1998                               Aquemini            OutKast
#
#             Genre                                           Subgenre  \
# Number
# ...

# %%
df['The Beatles'].describe()
# Out:
# count       500
# unique        2
# top       False
# freq        490
# Name: The Beatles, dtype: object

# %% [markdown]
# # 문자열 분리

# %%
import pandas as pd
df = pd.read_csv("C:/Users/gksal/Downloads/parks.csv")
df.head()
# Out:
#           관리번호       공원명  공원구분            소재지도로명주소          전화번호
# 0  29170-00001    문화근린공원  근린공원     광주광역시 북구 대천로 86  062-410-6438
# 1  29170-00002  두암제1근린공원  근린공원     광주광역시 북구 삼정로 36  062-410-6438
# 2  29170-00003  첨단체육근린공원  근린공원  광주광역시 북구 임방울대로 877  062-410-6438
# 3  29170-00004  일곡제1근린공원  근린공원     광주광역시 북구 일곡로 55  062-410-6438
# 4  29170-00005  일곡제2근린공원  근린공원    광주광역시 북구 설죽로 526  062-410-6438

# %%
df['소재지도로명주소'].str.split(n=1)
# Out:
# 0                [광주광역시, 북구 대천로 86]
# 1                [광주광역시, 북구 삼정로 36]
# 2             [광주광역시, 북구 임방울대로 877]
# 3                [광주광역시, 북구 일곡로 55]
# 4               [광주광역시, 북구 설죽로 526]
#                    ...
# 8117     [충청남도, 홍성군 홍성읍 오관리 472 일원]
# 8118     [경상북도, 영양군 영양읍 군민회관길 42-6]
# 8119    [경상북도, 영양군 입암면 신구리 산27-5번지]
# 8120      [경상북도, 영양군 수비면 발리리 산48번지]
# 8121      [경상북도, 영양군 영양읍 삼지리 200번지]
# Name: 소재지도로명주소, Length: 8122, dtype: object

# %%
address = df['소재지도로명주소'].str.split(n=1,expand=True)

# %%
df['관할구역'] = address[0]

# %%
df
# Out:
#              관리번호        공원명  공원구분                  소재지도로명주소          전화번호  \
# 0     29170-00001     문화근린공원  근린공원           광주광역시 북구 대천로 86  062-410-6438
# 1     29170-00002   두암제1근린공원  근린공원           광주광역시 북구 삼정로 36  062-410-6438
# 2     29170-00003   첨단체육근린공원  근린공원        광주광역시 북구 임방울대로 877  062-410-6438
# 3     29170-00004   일곡제1근린공원  근린공원           광주광역시 북구 일곡로 55  062-410-6438
# 4     29170-00005   일곡제2근린공원  근린공원          광주광역시 북구 설죽로 526  062-410-6438
# ...           ...        ...   ...                       ...           ...
# 8117  44800-00082  홍성읍24호소공원   소공원   충청남도 홍성군 홍성읍 오관리 472 일원  041-630-1268
# 8118  47760-00002       서부공원  근린공원   경상북도 영양군 영양읍 군민회관길 42-6  054-680-6340
# 8119  47760-00003       입암공원  근린공원  경상북도 영양군 입암면 신구리 산27-5번지  054-680-6340
# 8120  47760-00004       수비공원  근린공원    경상북도 영양군 수비면 발리리 산48번지  054-680-6340
# 8121  47760-00005  삼지연꽃 테마파크  수변공원    경상북도 영양군 영양읍 삼지리 200번지  054-680-6340
#
#        관할구역
# 0     광주광역시
# 1     광주광역시
# 2     광주광역시
# 3     광주광역시
# ...

# %% [markdown]
# # 카테고리로 분류

# %%
# %matplotlib inline
import pandas as pd
df = pd.read_csv("C:/Users/gksal/Downloads/laptops (1).csv")
df.head()
# Out:
#    brand             model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# 4           intel              i5          2.3              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# ...

# %%
brand_nation = {
    'Dell': 'US',
    'Apple': 'US',
    'Acer': 'Taiwan',
    'HP' : 'US',
    'Lenovo':'china',
    'Alienware':'US',
    'Microsoft': 'US',
    'Asus': 'Taiwan'
}

# %%
df['brand']
# Out:
# 0       Dell
# 1      Apple
# 2      Apple
# 3      Apple
# 4      Apple
#        ...
# 162     Asus
# 163     Asus
# 164     Asus
# 165     Asus
# 166     Asus
# Name: brand, Length: 167, dtype: object

# %%
df['brand'].map(brand_nation)
# Out:
# 0          US
# 1          US
# 2          US
# 3          US
# 4          US
#         ...
# 162    Taiwan
# 163    Taiwan
# 164    Taiwan
# 165    Taiwan
# 166    Taiwan
# Name: brand, Length: 167, dtype: object

# %%
df['brand_nation']= df['brand'].map(brand_nation)

# %%
df
# Out:
#      brand             model  ram hd_type  hd_size  screen_size   price  \
# 0     Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1    Apple       MacBook Air    8     ssd      128         13.3   55499
# 2    Apple       MacBook Air    8     ssd      256         13.3   71500
# 3    Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4    Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..     ...               ...  ...     ...      ...          ...     ...
# 162   Asus            A555LF    8     hdd     1024         15.6   39961
# 163   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 164   Asus            X554LD    2     hdd      500         15.6   29199
# 165   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 166   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# ...

# %% [markdown]
# # groupby

# %%
nation_groups = df.groupby('brand_nation')

# %%
type(nation_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
nation_groups.count()
# Out:
#               brand  model  ram  hd_type  hd_size  screen_size  price  \
# brand_nation
# Taiwan           44     44   44       44       44           44     44
# US              105    105  105      105      105          105    105
# china            18     18   18       18       18           18     18
#
#               processor_brand  processor_model  clock_speed  \
# brand_nation
# Taiwan                     44               44           44
# US                        105              105          104
# china                      18               18           18
#
#               graphic_card_brand  graphic_card_size   os  weight  comments
# brand_nation
# Taiwan                        43                 14   44      42         9
# US                           102                 50  105     100        28
# china                         18                 17   18      18        18

# %%
nation_groups.max()
# Out:
# C:\Users\gksal\AppData\Local\Temp/ipykernel_13668/145059863.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   nation_groups.max()
#                   brand                          model  ram hd_type  hd_size  \
# brand_nation
# Taiwan             Asus                  X555LA-XX172D   16     ssd     1024
# US            Microsoft                        ay516tx   16     ssd     2048
# china            Lenovo  IdeaPad 520-15IKB 80YL00RXIN     8     hdd     2048
#
#               screen_size   price processor_brand processor_model  \
# brand_nation
# Taiwan               17.3  178912           intel         pentium
# US                   17.6  226000           intel   pentium N3710
# china                15.6   69990           intel              i7
#
#               clock_speed  graphic_card_size       os  weight
# ...

# %%
nation_groups.mean()
# Out:
#                    ram      hd_size  screen_size         price  clock_speed  \
# brand_nation
# Taiwan        6.272727   726.363636    14.970455  53320.409091     2.164545
# US            7.314286   733.257143    14.603429  71541.295238     2.356346
# china         6.000000  1080.888889    15.300000  47347.777778     2.500000
#
#               graphic_card_size    weight
# brand_nation
# Taiwan               288.285714  2.242381
# US                     2.980000  2.216500
# china                  2.352941  2.461111

# %%
nation_groups.first()
# Out:
#                brand                model  ram hd_type  hd_size  screen_size  \
# brand_nation
# Taiwan          Acer  Predator Helios 300   16     ssd     1024         15.6
# US              Dell     Inspiron 15-3567    4     hdd     1024         15.6
# china         Lenovo            300–15IBR    8     hdd     1024         15.6
#
#                price processor_brand processor_model  clock_speed  \
# brand_nation
# Taiwan        101839           intel              i7          2.8
# US             40000           intel              i5          2.5
# china          40990           intel              i5          2.3
#
#              graphic_card_brand  graphic_card_size       os  weight  \
# brand_nation
# Taiwan                   nvidia                6.0  windows     2.7
# US                        intel                2.0    linux     2.5
# china                       amd                2.0    linux     3.2
#
#                          comments
# brand_nation
# ...

# %%
nation_groups.plot()
# Out:
# brand_nation
# Taiwan    AxesSubplot(0.125,0.125;0.775x0.755)
# US        AxesSubplot(0.125,0.125;0.775x0.755)
# china     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
graphic = df.groupby('graphic_card_brand')
graphic

# %%
graphic.plot(kind='box',y='price')
# Out:
# graphic_card_brand
# amd       AxesSubplot(0.125,0.125;0.775x0.755)
# intel     AxesSubplot(0.125,0.125;0.775x0.755)
# nvidia    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
graphic.plot(kind='hist',y='price')
# Out:
# graphic_card_brand
# amd       AxesSubplot(0.125,0.125;0.775x0.755)
# intel     AxesSubplot(0.125,0.125;0.775x0.755)
# nvidia    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# # 데이터 합치기
# ## 합치는 4가지 방법 : 1.inner join   2.left outer join  3.right outer join  4.full outer join

# %%
# !pip install seaborn
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
price_df = pd.read_csv("C:/Users/gksal/Downloads/vegetable_price.csv")
quantity_df = pd.read_csv("C:/Users/gksal/Downloads/vegetable_quantity.csv")

# %% [markdown]
# ## inner join

# %%
price_df
# Out:
#    Product  Price
# 0   Potato   3000
# 1    Onion   1600
# 2  Avocado   5000
# 3   Garlic   1200
# 4   Tomato   3500
# 5  Lettuce   2000
# 6   Carrot   2500

# %%
quantity_df
# Out:
#     Product  Quantity
# 0    Potato        25
# 1     Onion        31
# 2   Avocado        57
# 3    Pepper        46
# 4  Broccoli        25
# 5  Cucumber         9

# %%
pd.merge(price_df,quantity_df,on='Product') # inner join
# Out:
#    Product  Price  Quantity
# 0   Potato   3000        25
# 1    Onion   1600        31
# 2  Avocado   5000        57

# %%
pd.merge(price_df,quantity_df,on='Product',how='left')
# Out:
#    Product  Price  Quantity
# 0   Potato   3000      25.0
# 1    Onion   1600      31.0
# 2  Avocado   5000      57.0
# 3   Garlic   1200       NaN
# 4   Tomato   3500       NaN
# 5  Lettuce   2000       NaN
# 6   Carrot   2500       NaN

# %%
pd.merge(price_df,quantity_df,on='Product',how='right')
# Out:
#     Product   Price  Quantity
# 0    Potato  3000.0        25
# 1     Onion  1600.0        31
# 2   Avocado  5000.0        57
# 3    Pepper     NaN        46
# 4  Broccoli     NaN        25
# 5  Cucumber     NaN         9

# %%
pd.merge(price_df,quantity_df,on='Product',how='outer')
# Out:
#     Product   Price  Quantity
# 0    Potato  3000.0      25.0
# 1     Onion  1600.0      31.0
# 2   Avocado  5000.0      57.0
# 3    Garlic  1200.0       NaN
# 4    Tomato  3500.0       NaN
# 5   Lettuce  2000.0       NaN
# 6    Carrot  2500.0       NaN
# 7    Pepper     NaN      46.0
# 8  Broccoli     NaN      25.0
# 9  Cucumber     NaN       9.0
