# %% [markdown]
# # 다양한 seaborn 그래프
# ## statistical data visualization
# ## pdf = 확률밀도함수 : 데이터셋의 분포를 나타낸다.

# %%
# !pip install seaborn
import pandas as pd

# %%
import seaborn as sns

# %%
body_df=pd.read_csv("C:/Users/gksal/Downloads/body.csv",index_col=0)
body_df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
body_df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
#         ...
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
body_df['Height'].value_counts()
# Out:
# 174.9    13
# 172.5    13
# 173.2    12
# 175.3    12
# 175.2    12
#          ..
# 160.2     1
# 188.2     1
# 162.0     1
# 185.1     1
# 184.4     1
# Name: Height, Length: 262, dtype: int64

# %%
body_df['Height'].value_counts().sort_index()
# Out:
# 154.4    1
# 155.5    1
# 157.4    1
# 157.8    1
# 158.0    1
#         ..
# 190.3    1
# 191.2    1
# 191.8    1
# 192.4    1
# 193.1    1
# Name: Height, Length: 262, dtype: int64

# %%
body_df['Height'].value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(body_df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(body_df['Height'],bw=0.25) # bw : 그래프를 어떻게 부드럽게 만들것인가
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
body_df.plot(kind='hist',y='Height',bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(body_df['Height'],bins=15)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
body_df.plot(kind='box',y='Height')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(y=body_df['Height'])         # x=body_df['Height']로 하면 가로축으로 그려짐
# Out:
# <AxesSubplot:ylabel='Height'>

# %%
body_df.plot(kind='scatter',x='Height',y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(body_df['Height'],body_df['Weight'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.kdeplot(body_df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.kdeplot(body_df['Weight'])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
body_df.plot(kind='scatter',x='Height',y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.lmplot(data=body_df,x='Height',y='Weight')    # 회귀선 : 키를 기준으로 무게 예측

# %%
import pandas as pd
import seaborn as sns
laptops_df = pd.read_csv("C:/Users/gksal/Downloads/laptops (1).csv")
laptops_df.head()
# Out:
#    brand             model  ram hd_type  hd_size  screen_size   price  \
# 0   Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1  Apple       MacBook Air    8     ssd      128         13.3   55499
# 2  Apple       MacBook Air    8     ssd      256         13.3   71500
# 3  Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4  Apple       MacBook Pro    8     ssd      256         13.3  112666
#
#   processor_brand processor_model  clock_speed graphic_card_brand  \
# 0           intel              i5          2.5              intel
# 1           intel              i5          1.8              intel
# 2           intel              i5          1.8              intel
# 3           intel              i5          2.3              intel
# 4           intel              i5          2.3              intel
#
#    graphic_card_size     os  weight comments
# 0                NaN  linux    2.50      NaN
# 1                2.0    mac    1.35      NaN
# ...

# %%
laptops_df['os'].unique()
# Out:
# array(['linux', 'mac', 'windows'], dtype=object)

# %%
sns.catplot(data=laptops_df,x='os',y='price',kind='box')

# %%
sns.catplot(data=laptops_df,x='os',y='price',kind='strip')

# %%
laptops_df['processor_brand'].unique()
# Out:
# array(['intel', 'amd'], dtype=object)

# %%
sns.catplot(data=laptops_df,x='os',y='price',kind='strip',hue='processor_brand')

# %%
sns.catplot(data=laptops_df,x='os',y='price',kind='swarm',hue='processor_brand')

# %% [markdown]
# # 과제

# %%
df = pd.read_csv("C:/Users/gksal/Downloads/occupations.csv")
df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]
